# %% [markdown]
# <a href="https://colab.research.google.com/github/plear/UM/blob/main/587Group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import cv2
import scipy.io as sio
from PIL import Image


from google.colab import drive

drive.mount('/content/drive')

data = pd.read_csv('/content/drive/Shared drives/CSC587G3/Image Meta Data.csv')
print(data)


# open method used to open different extension image file
im = Image.open('/content/drive/Shared drives/CSC587G3/Dataset/cars_train/00001.jpg')  #PIL
img = cv2.imread('/content/drive/Shared drives/CSC587G3/Dataset/cars_train/00001.jpg') #CV2
  
string = im.tobytes()
#string = string.decode("ascii")

print(string)

img_flip_lr = cv2.flip(img, 1)
cv2.imwrite('/content/drive/Shared drives/CSC587G3/Dataset/cars_train/00001_f.jpg', img_flip_lr)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Unnamed: 0  Image                           Vehicle
# 0             1      1        AM General Hummer SUV 2000
# 1             2      2               Acura RL Sedan 2012
# 2             3      3               Acura TL Sedan 2012
# 3             4      4              Acura TL Type-S 2008
# 4             5      5              Acura TSX Sedan 2012
# ..          ...    ...                               ...
# 191         192    192  Volkswagen Beetle Hatchback 2012
# 192         193    193          Volvo C30 Hatchback 2012
# 193         194    194              Volvo 240 Sedan 1993
# 194         195    195               Volvo XC90 SUV 2007
# 195         196    196     smart fortwo Convertible 2012
#
# [196 rows x 3 columns]
# ...
